# %% [markdown]
# # Introduction
#
# A GANr (GAN with regressor) based on the paper ***Financial Thought Experiment: A GAN-based Approach to Vast Robust Portfolio Selection*** by Pun, Wang, and Wong. Pun supplied me with several *.R* files that he used for this paper. A specific file he named *CV min Var.R* was referenced and and re-implemented in PyTorch with some modifications. Though the broad architecture, training and deployment methodologies remain the same, neither the reference file nor this implementation is identical to the one in the paper.
#
# Refer to the penultimate cell of this notebook for **References**.
#
#
# # Data Preparation
#
# The raw data is daily stock prices for S&P500 companies, starting with the earliest date at the top and the latest and the bottom. Returns are calculated, then the dataframe is sliced to preserve returns for the years of 2015 and 2016.

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, optimizers, regularizers
from sklearn.linear_model import LassoCV, Lasso
import time

df = pd.read_csv(r"C:\Users\email\Downloads\sp500-0317.csv")

# Identify price columns (first column is Date)
prices_raw = df.iloc[:, 1:].apply(pd.to_numeric, errors='coerce')
# Drop any columns that contain ANY NaN values
prices = prices_raw.dropna(axis=1, how='any')
# Calculate returns and drop the first row (NaN from pct_change)
returns = prices.pct_change().dropna()
# Slice the returns DataFrame by index b/c to obtain years of 2015 and 2016
returns = returns.loc[3041:3541]
print("No. of assets:", len(returns.columns))
# Out:
# No. of assets: 410

# %% [markdown]
# # Model Definitions
#
# Descriptions consistent with Pun's.
#
# Generator: 1st 2 hidden layers adopt ReLU activation function w/ 0.25 dropout. Last 2 layers use tanh functions w/ 0 dropout. 5 layers: 1 input + 2 ReLU hidden + 2 tanh hidden.
#
# Discirminator: 3 hidden layers are identical to the generator’s, while its output layer uses a linear activation function with one output node.
#
# Regressor: No hidden layers and uses a linear activation function with one output node and *$l_1$* kernel regularizer.
#
# Controller: In a standard GAN, the Generator only tries to fool the Discriminator. In this code, the Generator has a second goal: it must produce returns that, when passed through a Regressor, match a specific target return ($r_p$). tanh function used to ensure this difference doesn't explode, smoothing out feedback sent back to the Generator so the model stays stable during training.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np

class Generator(nn.Module):
    def __init__(self, p):
        super(Generator, self).__init__()
        # Matches the 'one_hidden_layer' in R
        self.model = nn.Sequential(
            nn.Linear(p, p),
            nn.ReLU(),
            nn.Dropout(0.25),
            nn.Linear(p, p),
            nn.ReLU(),
            nn.Dropout(0.25),
            nn.Linear(p, p),
            nn.Tanh(),
            nn.Linear(p, p),
            nn.Tanh()
        )

    def forward(self, latent, rp):
        # layer_multiply(list(latent, rp))
        # Note: rp is (batch, 1), latent is (batch, p)
        h = latent * rp 
        return self.model(h)

class Discriminator(nn.Module):
    def __init__(self, p):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Linear(p, p),
            nn.ReLU(),
            nn.Dropout(0.25),
            nn.Linear(p, p),
            nn.ReLU(),
            nn.Dropout(0.25),
            nn.Linear(p, 1) # 'linear' activation
        )

    def forward(self, returns, rp):
        # layer_multiply(list(return, rp))
        h = returns * rp
        return self.model(h)

class Regressor(nn.Module):
    def __init__(self, p):
        super(Regressor, self).__init__()
        self.fc = nn.Linear(p, 1, bias=True)

    def forward(self, x):
        return self.fc(x)

    @torch.no_grad() # This prevents PyT from calculating gradients for this specific operation 
    def apply_lasso(self, l1_lambda, lr):
        """
        Applies the Proximal Operator (Soft-Thresholding) to the weights.
        This is the built-in mathematical equivalent of L1 regularization.
        """
        # We only apply this to the weights, usually not the bias
        w = self.fc.weight # Grab current weights
         
        # Lasso shrinkage amount
        shrinkage = l1_lambda * lr
        
        # Soft-thresholding formula: sign(w) * max(abs(w) - shrinkage, 0)
        self.fc.weight.copy_( # This line overwrites old weights w/ new weights 
            torch.sign(w) * torch.max(torch.abs(w) - shrinkage, torch.zeros_like(w))
        )


""" Controller intakes a vector that is the regressor's error, and passes each element into a tanh function. Effectively transforming every element. """
class Controller(nn.Module):
    def __init__(self):
        super(Controller, self).__init__()
        # use_bias = F, initializer_constant(1)
        self.fc = nn.Linear(1, 1, bias=False) # No bias b/c we want output of 0 for 0 error 
        with torch.no_grad(): # Don't track by autograd b/c not part of training 
            self.fc.weight.fill_(1.0) # Initialize weight vector as a column of 1s b/c controller is not there to change any values 

    def forward(self, x):
        return torch.tanh(self.fc(x)) # tanh squashes output in range (-1, 1)


# --- Loss Function ---
# The R code uses 'wass' which is defined as mean((y_pred - y_true)^2)
# effectively an MSE loss in this specific script context.
def wass_loss(y_pred, y_true):
    return torch.mean((y_pred - y_true)**2)

# %% [markdown]
# # Training Functions
#
# `train_batch` is `ret_train_centered[indices]`, the excess retruns of each asset from the EWP (Evenly Weighted Portfolio) in a 250x410 tensor
#
# `r_p_batch` is `r_p[indices]`, a 250x1 tensor, the average return of all assets per day i.e. return of EWP
#
# `r_p_min_max` is `r_p_range`, a 2-element list, showing the maximum and minimum of the `r_p[indices]` i.e. min and max of theEWP return
#
#
# Per epoch, the following occurs chronologically
#
# ### **1.**
#
# Through the `get_best_l1_lambda` function, the **real** excess returns of each asset from the EWP in a [No. of days, 410] tensor is used. It splits the data into 5 contiguous folds, applying 5-fold CV (Cross-Validaiton) through a LASSO regressor, obtaining the necessary weights to match the returns of an EWP. It selects the best λ based on the lowest variance of test folds. This sole use of this function is to obtain the best λ.
#
#
# ### **2.**
#
# 50 random observations are selected (not necessarily contiguous times).
#
# `ret_train_centered[indices]` is the excess retruns of each asset from the EWP in a [no. of days, 410] tensor.
#
# `r_p[indices]` is a [no. of days, 1] tensor, the average return of all assets per day i.e. return of EWP.
#
# `r_p_range` 2-element list, showing the maximum and minimum of the `r_p[indices]` i.e. min and max of the EWP return.
#
# These enter the `train_step` function. Synthetic asset returns and EWP returns are created, and are a function of
#
# • Noise
# • Minimum and maximum of the real returns
#
# Then fed into the Generator. This is the condition for the Generator, whose goal is to create a universe of possible asset returns that achieves the synthetic EWP return. Thus, each set of synthetic returns has an associated set of real returns.
#
# The real and synthetic returns and concatenated. The real values are labeled as 1, synthetic as 0. These are fed to the Discriminator whose goal is to correctly label these, training it and updating its weight.
#
# The LASSO regressor is trained on both real and synthetic data. It determines a set of weights whose total return matches that of the EWP, while using the best λ in step 1. Note that this only occurs for the 2nd half of the training epochs, because the Generator and Discriminator losses should be allowed to stabilize before training the regressor, to ensure that the regressor is trained on high fidelity synthetic data. LASSO's *$l_1$* regualrization allows weights to be forced to 0 ensuring robust and selective asset choices.
#
# Then, a new batch of synthetic data (`fake_gen`) based on the same set of real data is created using the Generator. This synthetic data has reversed labels, labeled as 1 for real, then **only** this synthetic data is fed to the Discriminator. `loss_wass = torch.mean((res1 - 1.0)**2)` is the Generator's realism loss. Synthetic data **only** (`fake_gen`) is input into the Regressor, which attempts to find a weighted combination of assets whose returns matches that of the synthetic EWP. `intermediate = rp_gen - reg(fake_gen)` is the loss of the regressor, which is fed into the Controller to convert that loss into a value in the range (-1,1), which is the Controller's loss. The Generator's total loss is thus the sum `total_gen_loss = loss_wass - (params['ratio'] * loss_mse)`. The negative sign attributed in `-params[ratio]` turns the Generator into an adversarial stress-tester. In a typical GAN, loss is minimized. Here it is maximized. If a positive sign was used instead the Generator would create easy data that perfectly matches the portfolio

# %% [markdown]
# # Rolling Window
#
# The first 250 days are used to train GANr, and tested on the 251st day. The initial training uses 1k epochs. Subsequent training cycles causes the window to roll forward, training on days 1 to 251, and tested on the 252nd day, inheriting GANr's weights from the previous training phase, then re-trained using 50 epochs. This assumes that the data distribution does not shift by much, training epochs drops to 50.
#
#
# # Misc.
#
# In Pun's reference file, paper, and this implementation a 0.0001 LR was used.
#
# In the reference file and this implementation, Adam optimizer was used, but in the paper RMSProp was used.
#
# In the reference file 20k epochs was used for the initial training, in the paper 10k was used. In this implementation, 1k was used as the Generator and Discriminator loss already stabilize before 1k epochs, oscillating stably around a mean.

# %%
""" In Pun's work, he selected best lambda by lowest MSE. Here I do so by lowest variance to reduce portfolio variance. """

def get_best_l1_lambda(ret_train, r_p):
    """
    K-Fold Cross-Validation to find the lambda that minimizes portfolio variance.
    """
    lambdas = torch.logspace(-10, 0, steps=20) # 20 candidate values
    K = 5
    fold_size = len(ret_train) // K
    best_lambda = lambdas[0]
    min_var = float('inf')

    for l_val in lambdas:
        fold_vars = [] # Hold the variance for each test fold 
        for k in range(K):
            # Define contiguous indices for this fold as in Pun's paper, but he used 12 folds not 5 in the paper, and 4 folds in his R code
            start, end = k * fold_size, (k + 1) * fold_size
            val_idx = list(range(start, end))
            train_idx = [i for i in range(len(ret_train)) if i not in val_idx]
            
            x_train, y_train = ret_train[train_idx], r_p[train_idx]
            x_val = ret_train[val_idx]
            
            # 1. Solve for weights using OLS (standard solver)
            # We use the solver to get 'base' weights
            w = torch.linalg.lstsq(x_train, y_train).solution
            
            # 2. Apply the L1 candidate (Manual soft-thresholding for CV speed)
            # This mimics the Regressor's behavior during the GAN training
            w_lasso = torch.sign(w) * torch.max(torch.abs(w) - l_val.item(), torch.zeros_like(w))
            
            # 3. Test on held-out fold
            preds = x_val @ w_lasso
            fold_vars.append(torch.var(preds).item())
        
        avg_var = sum(fold_vars) / K
        if avg_var < min_var:
            min_var = avg_var
            best_lambda = l_val
            
    return best_lambda.item()



def train_step(models, optimizers, data_tuple, params):
    """
    Replicates the inner num_batch loop in R.
    data_tuple: (train_batch, r_p_batch, r_p_range)
    """
    gen, disc, reg, cont = models
    opt_gen, opt_disc, opt_reg = optimizers
    train_batch, r_p_batch, r_p_min_max = data_tuple
    batch_size = train_batch.shape[0]
    p = train_batch.shape[1] # No. of columns (assets)
    
    # --- A. Train Discriminator ---
    opt_disc.zero_grad() # Resets gradients for Discriminator so previous test days don't interfere
    
    # Generate fake returns
    noise = torch.rand(batch_size, p) # 2D tensor w/ random values b/w 0 and 1
    rp_fake = (r_p_min_max[1] - r_p_min_max[0]) * torch.rand(batch_size, 1) + r_p_min_max[0] # Synthetic historical returns within observed historical range 
    generated_return = gen(noise, rp_fake) # Generator intakes noise, and target return, to create fake stock returns
    
    # Combine Real and Fake for Discriminator
    # R logic: predictor = abind(train_batch, generated_return)
    disc_input = torch.cat([train_batch, generated_return.detach()], dim=0) # Combines real and fake returns into 1 batch. ".detach:" tells PyT to cut the connection to the computational graph, keeping just the no.s, forgetting how they were calculated. Important b/c w/o it the gradients would flow backwards from the Discriminator and keep going into the Generator, causing the Generator to update weights based on Discriminator's loss function at the wrong time.
    disc_rp = torch.cat([r_p_batch.view(-1, 1), rp_fake], dim=0) # 1D tensor, so we change it into a 2D [50 ,1] tensor (remember that batch size is 50)
    real_fake_labels = torch.cat([torch.ones(batch_size, 1), torch.zeros(batch_size, 1)], dim=0) # Labelling real as 1, fake as 0. Mechanically this creates a [50, 1] tensor of 1s, and another same tensor of 0s, and concatenates them
    
    disc_preds = disc(disc_input, disc_rp) # Pass fake and real data, and their labels, into discriminator, and the results come out as a [100 ,1] tensor no.s from 0 to 1, higher number means more confidence that the data is real 
    loss_disc = torch.mean((disc_preds - real_fake_labels)**2) # Wass loss as MSE
    
    loss_disc.backward() # Back-propagation step, which comes after you compute the error
    opt_disc.step() # Act of changing the model 


    # --- B. Train Regressor W/ Built-in LASSO ---
    # Regressor trained on real and syntehtic data
    loss_reg_val = torch.tensor(0.0) # Placeholder single number for the score 
    if params['train_reg']: # Esures the training only runs in the 2nd half of training epochs. We want the GAN to stabilize before regressor acts
        opt_reg.zero_grad() # Resets gradients so previous test days don't interfere
        reg_preds = reg(disc_input) # Training on same data as disc, a [100, 410] tensor
        
        # MSE loss 
        loss_reg = torch.mean((reg_preds - disc_rp)**2)
        
        loss_reg.backward()
        opt_reg.step()
        
        # APPLY BUILT-IN LASSO STEP
        # We pass the lambda and the learning rate from the optimizer
        reg.apply_lasso(params['l1_lambda'], opt_reg.param_groups[0]['lr'])
        
        loss_reg_val = loss_reg.detach() # Saves the score as a simple no.


    # --- C. Train Generator (Combined Model) ---
    opt_gen.zero_grad() # Resets gradients so previous test days don't interfere
    
    # New noise for generator step
    noise_gen = torch.rand(batch_size * 2, p)
    rp_gen = (r_p_min_max[1] - r_p_min_max[0]) * torch.rand(batch_size * 2, 1) + r_p_min_max[0] # Vector of random EWP returns
    fake_gen = gen(noise_gen, rp_gen) # Generator intakes noise, and targeted returns, outputs [100, p] tensor, each row is a simulated day, each column a stock's excess returns
    
    # We want Discriminator to think these are '1' (real)
    res1 = disc(fake_gen, rp_gen) # Feed synthetic data into Discriminator, and the results come out as a [100 ,1] tensor no.s from 0 to 1, higher number means more confidence that the data is real
    loss_wass = torch.mean((res1 - 1.0)**2) # A "1" is a real label, defined earlier, Generator's loss is the square of the gap b/w the Discriminator and the "1" label b/c we want the Generator to fool the Discriminator into labelling synthetic data as real
    
    # Portfolio constraint via Regressor and Controller
    # intermediate = rp - regressor(fake)
    intermediate = rp_gen - reg(fake_gen) # Difference b/w the EWP return and regressor return, this is a vector
    res2 = cont(intermediate) # Regressor's error is input into controller, and the output is a value in range (-1, 1), larger input error pushes controller output further to 1 or -1
    loss_mse = torch.mean(res2**2) # Controller's loss, ideally this should be 0. Finds mean of all the squared values in the output vector of the controller. 
    
    # Total Loss = wass_loss + (-ratio * mse_loss)
    '''The -ve sign in the ratio turns the Generator into an adversarial stress-tester. In a normal GAN we want to minimize loss. Here we maximize it.
    If we used a +ve sign the Generator would create easy data that perfectly matches the portfolio '''
    total_gen_loss = loss_wass - (params['ratio'] * loss_mse)
    
    total_gen_loss.backward()
    opt_gen.step()
    
    return loss_disc.item(), loss_reg_val.item(), total_gen_loss.item()


# Convert to Tensor
data_tensor = torch.tensor(returns.values, dtype=torch.float32)
p = data_tensor.shape[1]  # Number of stocks
year = 250                # Training window
month = 1                 # Forecast/Test horizon (test on the 251st row), IDK why called month

# Initialize Models
gen = Generator(p)
disc = Discriminator(p)
reg = Regressor(p)
cont = Controller()
models = (gen, disc, reg, cont)

# Optimizers
opt_gen = optim.Adam(gen.parameters(), lr=0.0001)
opt_disc = optim.Adam(disc.parameters(), lr=0.0001)
opt_reg = optim.Adam(reg.parameters(), lr=0.0001)
optimizers = (opt_gen, opt_disc, opt_reg)


wealth_history = [] # Store daily returns
ratio = 0.2 # This is either the µ value or the µg value

# Total number of sliding windows
I = len(data_tensor) - year

for i in range(I):
    # 1. Slice  Window
    # train_idx will be 0:250, then 1:251, etc.
    # test_idx will be 250, then 251, etc.
    train_idx = slice(i, i + year) # This is a slice obj, tells us the start and stop indices for training
    test_idx = i + year
    
    ret_train = data_tensor[train_idx]
    ret_test = data_tensor[test_idx]
    
    # Calculate the evenly weighted portfolio return (Condition)
    r_p = ret_train.mean(dim=1) # 1D, 250x1 tensor, mean returns of each asset
    r_p_range = [r_p.min().item(), r_p.max().item()] # List to store max and min values of the EWP
    
    # Center the returns (as done in the R code: ret.train - r.p)
    ret_train_centered = ret_train - r_p.view(-1, 1) # Subtracts portfolio mean return from each asset return row-wise

    # --- 1. CROSS-VALIDATION STEP ---
    # This finds the best lambda for THIS specific 250-day window
    best_l1 = get_best_l1_lambda(ret_train_centered, r_p)
    print(f"Window {i+1}: Optimized L1 Lambda = {best_l1:.10f}")
    # ----------------------------------
    
    # 2. Training Phase
    # First window needs heavy training, subsequent windows are fine-tuned (50)
    epochs = 2000 if i == 0 else 50

    # Store loss history as lists for initial training window
    if i == 0:
        d_hist, r_hist, g_hist = [], [], []
    
    for epoch in range(1, epochs + 1):
        # We manually draw a batch of 50 days from the 250 available
        indices = torch.randperm(year)[:50] # 50 random permutation of integers from 0 to 250-1 
        batch_data = (ret_train_centered[indices], r_p[indices], r_p_range) # 3-element tuple
        
        params = {
            'ratio': ratio,
            'train_reg': epoch > (epochs // 2), # Simple T/F when it goes into train_step function
            'l1_lambda': best_l1
        }
        
        d_loss, r_loss, g_loss = train_step(models, optimizers, batch_data, params)

        # Store loss history for the 1st initial training window only
        if i == 0:
            d_hist.append(d_loss), r_hist.append(r_loss), g_hist.append(g_loss)
        
        if epoch % 100 == 0 and i == 0:
            print(f"Initial Training - Epoch {epoch}: D_Loss: {d_loss:.4f}, G_Loss: {g_loss:.4f}")

    # 3. Deployment Phase (Calculate Weights for day 251)
    with torch.no_grad():
        # Get weights from Regressor (Lasso Portfolio)
        weights = reg.fc.weight.data.clone().view(-1)
        
        # Apply R logic: Normalize weights to sum to 1
        weights = weights + (1/p) * (1 - torch.sum(weights))
        
        # Calculate return for the test day (day 251)
        # Wealth = sum(weights * (returns + 1))
        daily_return = torch.sum(weights * (ret_test + 1))
        wealth_history.append(daily_return.item())
        
    print(f"Window {i+1}/{I} complete. Test Day Return: {daily_return.item():.4f}")
# Out:
# Window 1: Optimized L1 Lambda = 0.2976351380
# Initial Training - Epoch 100: D_Loss: 0.2536, G_Loss: 0.1603
# Initial Training - Epoch 200: D_Loss: 0.2344, G_Loss: 0.1108
# Initial Training - Epoch 300: D_Loss: 0.2203, G_Loss: 0.1560
# Initial Training - Epoch 400: D_Loss: 0.2263, G_Loss: 0.2274
# Initial Training - Epoch 500: D_Loss: 0.2166, G_Loss: 0.2641
# Initial Training - Epoch 600: D_Loss: 0.2333, G_Loss: 0.2380
# Initial Training - Epoch 700: D_Loss: 0.2472, G_Loss: 0.2295
# Initial Training - Epoch 800: D_Loss: 0.2479, G_Loss: 0.2326
# Initial Training - Epoch 900: D_Loss: 0.2509, G_Loss: 0.2344
# Initial Training - Epoch 1000: D_Loss: 0.2451, G_Loss: 0.2345
# Initial Training - Epoch 1100: D_Loss: 0.2535, G_Loss: 0.2465
# Initial Training - Epoch 1200: D_Loss: 0.2497, G_Loss: 0.2428
# Initial Training - Epoch 1300: D_Loss: 0.2550, G_Loss: 0.2610
# Initial Training - Epoch 1400: D_Loss: 0.2506, G_Loss: 0.2493
# Initial Training - Epoch 1500: D_Loss: 0.2468, G_Loss: 0.2514
# Initial Training - Epoch 1600: D_Loss: 0.2498, G_Loss: 0.2544
# Initial Training - Epoch 1700: D_Loss: 0.2548, G_Loss: 0.2550
# Initial Training - Epoch 1800: D_Loss: 0.2490, G_Loss: 0.2559
# Initial Training - Epoch 1900: D_Loss: 0.2495, G_Loss: 0.2484
# Initial Training - Epoch 2000: D_Loss: 0.2520, G_Loss: 0.2533
# Window 1/251 complete. Test Day Return: 1.0284
# Window 2: Optimized L1 Lambda = 0.2976351380
# Window 2/251 complete. Test Day Return: 1.0008
# Window 3: Optimized L1 Lambda = 0.2976351380
# Window 3/251 complete. Test Day Return: 0.9777
# Window 4: Optimized L1 Lambda = 0.2976351380
# Window 4/251 complete. Test Day Return: 1.0109
# Window 5: Optimized L1 Lambda = 0.2976351380
# Window 5/251 complete. Test Day Return: 1.0050
# Window 6: Optimized L1 Lambda = 0.2976351380
# Window 6/251 complete. Test Day Return: 0.9824
# Window 7: Optimized L1 Lambda = 0.2976351380
# Window 7/251 complete. Test Day Return: 0.9783
# Window 8: Optimized L1 Lambda = 0.2976351380
# Window 8/251 complete. Test Day Return: 0.9980
# Window 9: Optimized L1 Lambda = 0.2976351380
# Window 9/251 complete. Test Day Return: 1.0012
# Window 10: Optimized L1 Lambda = 0.2976351380
# Window 10/251 complete. Test Day Return: 0.9846
# Window 11: Optimized L1 Lambda = 0.2976351380
# Window 11/251 complete. Test Day Return: 1.0221
# Window 12: Optimized L1 Lambda = 0.2976351380
# Window 12/251 complete. Test Day Return: 1.0203
# Window 13: Optimized L1 Lambda = 0.2976351380
# Window 13/251 complete. Test Day Return: 1.0174
# Window 14: Optimized L1 Lambda = 0.2976351380
# Window 14/251 complete. Test Day Return: 0.9958
# Window 15: Optimized L1 Lambda = 0.2976351380
# Window 15/251 complete. Test Day Return: 0.9994
# Window 16: Optimized L1 Lambda = 0.2976351380
# Window 16/251 complete. Test Day Return: 1.0192
# Window 17: Optimized L1 Lambda = 0.2976351380
# Window 17/251 complete. Test Day Return: 0.9868
# Window 18: Optimized L1 Lambda = 0.2976351380
# Window 18/251 complete. Test Day Return: 1.0061
# Window 19: Optimized L1 Lambda = 0.2976351380
# Window 19/251 complete. Test Day Return: 1.0116
# Window 20: Optimized L1 Lambda = 0.2976351380
# Window 20/251 complete. Test Day Return: 1.0029
# Window 21: Optimized L1 Lambda = 0.2976351380
# Window 21/251 complete. Test Day Return: 0.9933
# Window 22: Optimized L1 Lambda = 0.2976351380
# Window 22/251 complete. Test Day Return: 1.0239
# Window 23: Optimized L1 Lambda = 0.2976351380
# Window 23/251 complete. Test Day Return: 1.0096
# Window 24: Optimized L1 Lambda = 0.2976351380
# Window 24/251 complete. Test Day Return: 1.0089
# Window 25: Optimized L1 Lambda = 0.2976351380
# Window 25/251 complete. Test Day Return: 1.0055
# Window 26: Optimized L1 Lambda = 0.2976351380
# Window 26/251 complete. Test Day Return: 1.0042
# Window 27: Optimized L1 Lambda = 0.2976351380
# Window 27/251 complete. Test Day Return: 0.9837
# Window 28: Optimized L1 Lambda = 0.2976351380
# Window 28/251 complete. Test Day Return: 1.0062
# Window 29: Optimized L1 Lambda = 0.2976351380
# Window 29/251 complete. Test Day Return: 1.0011
# Window 30: Optimized L1 Lambda = 0.2976351380
# Window 30/251 complete. Test Day Return: 1.0210
# Window 31: Optimized L1 Lambda = 0.2976351380
# Window 31/251 complete. Test Day Return: 0.9980
# Window 32: Optimized L1 Lambda = 0.2976351380
# Window 32/251 complete. Test Day Return: 0.9954
# Window 33: Optimized L1 Lambda = 0.2976351380
# Window 33/251 complete. Test Day Return: 1.0093
# Window 34: Optimized L1 Lambda = 0.2976351380
# Window 34/251 complete. Test Day Return: 1.0094
# Window 35: Optimized L1 Lambda = 0.2976351380
# Window 35/251 complete. Test Day Return: 1.0061
# Window 36: Optimized L1 Lambda = 0.2976351380
# Window 36/251 complete. Test Day Return: 0.9991
# Window 37: Optimized L1 Lambda = 0.2976351380
# Window 37/251 complete. Test Day Return: 0.9994
# Window 38: Optimized L1 Lambda = 0.2976351380
# Window 38/251 complete. Test Day Return: 0.9885
# Window 39: Optimized L1 Lambda = 0.2976351380
# Window 39/251 complete. Test Day Return: 0.9997
# Window 40: Optimized L1 Lambda = 0.2976351380
# Window 40/251 complete. Test Day Return: 1.0012
# Window 41: Optimized L1 Lambda = 0.2976351380
# Window 41/251 complete. Test Day Return: 1.0104
# Window 42: Optimized L1 Lambda = 0.2976351380
# Window 42/251 complete. Test Day Return: 1.0035
# Window 43: Optimized L1 Lambda = 0.2976351380
# Window 43/251 complete. Test Day Return: 1.0013
# Window 44: Optimized L1 Lambda = 0.2976351380
# Window 44/251 complete. Test Day Return: 1.0033
# Window 45: Optimized L1 Lambda = 0.2976351380
# Window 45/251 complete. Test Day Return: 0.9945
# Window 46: Optimized L1 Lambda = 0.2976351380
# Window 46/251 complete. Test Day Return: 0.9894
# Window 47: Optimized L1 Lambda = 0.2976351380
# Window 47/251 complete. Test Day Return: 1.0115
# Window 48: Optimized L1 Lambda = 0.2976351380
# Window 48/251 complete. Test Day Return: 0.9878
# Window 49: Optimized L1 Lambda = 0.2976351380
# Window 49/251 complete. Test Day Return: 1.0057
# Window 50: Optimized L1 Lambda = 0.2976351380
# Window 50/251 complete. Test Day Return: 0.9984
# Window 51: Optimized L1 Lambda = 0.2976351380
# Window 51/251 complete. Test Day Return: 1.0132
# Window 52: Optimized L1 Lambda = 0.2976351380
# Window 52/251 complete. Test Day Return: 1.0115
# Window 53: Optimized L1 Lambda = 0.2976351380
# Window 53/251 complete. Test Day Return: 0.9980
# Window 54: Optimized L1 Lambda = 0.2976351380
# Window 54/251 complete. Test Day Return: 1.0005
# Window 55: Optimized L1 Lambda = 0.2976351380
# Window 55/251 complete. Test Day Return: 1.0076
# Window 56: Optimized L1 Lambda = 0.2976351380
# Window 56/251 complete. Test Day Return: 1.0061
# Window 57: Optimized L1 Lambda = 0.2976351380
# Window 57/251 complete. Test Day Return: 1.0010
# Window 58: Optimized L1 Lambda = 0.2976351380
# Window 58/251 complete. Test Day Return: 0.9924
# Window 59: Optimized L1 Lambda = 0.2976351380
# Window 59/251 complete. Test Day Return: 1.0079
# Window 60: Optimized L1 Lambda = 0.2976351380
# Window 60/251 complete. Test Day Return: 0.9954
# Window 61: Optimized L1 Lambda = 0.2976351380
# Window 61/251 complete. Test Day Return: 1.0072
# Window 62: Optimized L1 Lambda = 0.2976351380
# Window 62/251 complete. Test Day Return: 1.0066
# Window 63: Optimized L1 Lambda = 0.2976351380
# Window 63/251 complete. Test Day Return: 0.9874
# Window 64: Optimized L1 Lambda = 0.2976351380
# Window 64/251 complete. Test Day Return: 0.9943
# Window 65: Optimized L1 Lambda = 0.2976351380
# Window 65/251 complete. Test Day Return: 1.0064
# Window 66: Optimized L1 Lambda = 0.2976351380
# Window 66/251 complete. Test Day Return: 0.9879
# Window 67: Optimized L1 Lambda = 0.2976351380
# Window 67/251 complete. Test Day Return: 0.9927
# Window 68: Optimized L1 Lambda = 0.2976351380
# Window 68/251 complete. Test Day Return: 0.9991
# Window 69: Optimized L1 Lambda = 0.2976351380
# Window 69/251 complete. Test Day Return: 1.0029
# Window 70: Optimized L1 Lambda = 0.2976351380
# Window 70/251 complete. Test Day Return: 0.9980
# Window 71: Optimized L1 Lambda = 0.2976351380
# Window 71/251 complete. Test Day Return: 1.0133
# Window 72: Optimized L1 Lambda = 0.2976351380
# Window 72/251 complete. Test Day Return: 0.9932
# Window 73: Optimized L1 Lambda = 0.2976351380
# Window 73/251 complete. Test Day Return: 0.9994
# Window 74: Optimized L1 Lambda = 0.2976351380
# Window 74/251 complete. Test Day Return: 0.9914
# Window 75: Optimized L1 Lambda = 0.2976351380
# Window 75/251 complete. Test Day Return: 1.0118
# Window 76: Optimized L1 Lambda = 0.2976351380
# Window 76/251 complete. Test Day Return: 0.9934
# Window 77: Optimized L1 Lambda = 0.2976351380
# Window 77/251 complete. Test Day Return: 0.9975
# Window 78: Optimized L1 Lambda = 0.2976351380
# Window 78/251 complete. Test Day Return: 0.9971
# Window 79: Optimized L1 Lambda = 0.2976351380
# Window 79/251 complete. Test Day Return: 1.0085
# Window 80: Optimized L1 Lambda = 0.2976351380
# Window 80/251 complete. Test Day Return: 0.9990
# Window 81: Optimized L1 Lambda = 0.2976351380
# Window 81/251 complete. Test Day Return: 1.0132
# Window 82: Optimized L1 Lambda = 0.2976351380
# Window 82/251 complete. Test Day Return: 1.0096
# Window 83: Optimized L1 Lambda = 0.2976351380
# Window 83/251 complete. Test Day Return: 0.9984
# Window 84: Optimized L1 Lambda = 0.2976351380
# Window 84/251 complete. Test Day Return: 1.0043
# Window 85: Optimized L1 Lambda = 0.2976351380
# Window 85/251 complete. Test Day Return: 1.0011
# Window 86: Optimized L1 Lambda = 0.2976351380
# Window 86/251 complete. Test Day Return: 1.0015
# Window 87: Optimized L1 Lambda = 0.2976351380
# Window 87/251 complete. Test Day Return: 1.0044
# Window 88: Optimized L1 Lambda = 0.2976351380
# Window 88/251 complete. Test Day Return: 0.9972
# Window 89: Optimized L1 Lambda = 0.2976351380
# Window 89/251 complete. Test Day Return: 1.0083
# Window 90: Optimized L1 Lambda = 0.2976351380
# Window 90/251 complete. Test Day Return: 1.0042
# Window 91: Optimized L1 Lambda = 0.2976351380
# Window 91/251 complete. Test Day Return: 1.0041
# Window 92: Optimized L1 Lambda = 0.2976351380
# Window 92/251 complete. Test Day Return: 0.9968
# Window 93: Optimized L1 Lambda = 0.2976351380
# Window 93/251 complete. Test Day Return: 0.9854
# Window 94: Optimized L1 Lambda = 0.2976351380
# Window 94/251 complete. Test Day Return: 0.9923
# Window 95: Optimized L1 Lambda = 0.2976351380
# Window 95/251 complete. Test Day Return: 0.9970
# Window 96: Optimized L1 Lambda = 0.2976351380
# Window 96/251 complete. Test Day Return: 1.0012
# Window 97: Optimized L1 Lambda = 0.2976351380
# Window 97/251 complete. Test Day Return: 1.0004
# Window 98: Optimized L1 Lambda = 0.2976351380
# Window 98/251 complete. Test Day Return: 1.0037
# Window 99: Optimized L1 Lambda = 0.2976351380
# Window 99/251 complete. Test Day Return: 1.0115
# Window 100: Optimized L1 Lambda = 0.2976351380
# Window 100/251 complete. Test Day Return: 1.0035
# Window 101: Optimized L1 Lambda = 0.2976351380
# Window 101/251 complete. Test Day Return: 0.9972
# Window 102: Optimized L1 Lambda = 0.2976351380
# Window 102/251 complete. Test Day Return: 1.0163
# Window 103: Optimized L1 Lambda = 0.2976351380
# Window 103/251 complete. Test Day Return: 0.9581
# Window 104: Optimized L1 Lambda = 0.2976351380
# Window 104/251 complete. Test Day Return: 0.9721
# Window 105: Optimized L1 Lambda = 0.2976351380
# Window 105/251 complete. Test Day Return: 1.0232
# Window 106: Optimized L1 Lambda = 0.2976351380
# Window 106/251 complete. Test Day Return: 1.0193
# Window 107: Optimized L1 Lambda = 0.2976351380
# Window 107/251 complete. Test Day Return: 1.0152
# Window 108: Optimized L1 Lambda = 0.2976351380
# Window 108/251 complete. Test Day Return: 1.0051
# Window 109: Optimized L1 Lambda = 0.2976351380
# Window 109/251 complete. Test Day Return: 0.9857
# Window 110: Optimized L1 Lambda = 0.2976351380
# Window 110/251 complete. Test Day Return: 1.0075
# Window 111: Optimized L1 Lambda = 0.2976351380
# Window 111/251 complete. Test Day Return: 0.9988
# Window 112: Optimized L1 Lambda = 0.2976351380
# Window 112/251 complete. Test Day Return: 1.0185
# Window 113: Optimized L1 Lambda = 0.2976351380
# Window 113/251 complete. Test Day Return: 1.0036
# Window 114: Optimized L1 Lambda = 0.2976351380
# Window 114/251 complete. Test Day Return: 1.0166
# Window 115: Optimized L1 Lambda = 0.2976351380
# Window 115/251 complete. Test Day Return: 0.9983
# Window 116: Optimized L1 Lambda = 0.2976351380
# Window 116/251 complete. Test Day Return: 1.0040
# Window 117: Optimized L1 Lambda = 0.2976351380
# Window 117/251 complete. Test Day Return: 0.9996
# Window 118: Optimized L1 Lambda = 0.2976351380
# Window 118/251 complete. Test Day Return: 1.0021
# Window 119: Optimized L1 Lambda = 0.2976351380
# Window 119/251 complete. Test Day Return: 0.9941
# Window 120: Optimized L1 Lambda = 0.2976351380
# Window 120/251 complete. Test Day Return: 1.0049
# Window 121: Optimized L1 Lambda = 0.2976351380
# Window 121/251 complete. Test Day Return: 0.9978
# Window 122: Optimized L1 Lambda = 0.2976351380
# Window 122/251 complete. Test Day Return: 1.0050
# Window 123: Optimized L1 Lambda = 0.2976351380
# Window 123/251 complete. Test Day Return: 0.9950
# Window 124: Optimized L1 Lambda = 0.2976351380
# Window 124/251 complete. Test Day Return: 1.0066
# Window 125: Optimized L1 Lambda = 0.2976351380
# Window 125/251 complete. Test Day Return: 0.9944
# Window 126: Optimized L1 Lambda = 0.2976351380
# Window 126/251 complete. Test Day Return: 1.0031
# Window 127: Optimized L1 Lambda = 0.2976351380
# Window 127/251 complete. Test Day Return: 1.0033
# Window 128: Optimized L1 Lambda = 0.2976351380
# Window 128/251 complete. Test Day Return: 0.9914
# Window 129: Optimized L1 Lambda = 0.2976351380
# Window 129/251 complete. Test Day Return: 0.9915
# Window 130: Optimized L1 Lambda = 0.2976351380
# Window 130/251 complete. Test Day Return: 1.0090
# Window 131: Optimized L1 Lambda = 0.2976351380
# Window 131/251 complete. Test Day Return: 0.9992
# Window 132: Optimized L1 Lambda = 0.2976351380
# Window 132/251 complete. Test Day Return: 1.0095
# Window 133: Optimized L1 Lambda = 0.2976351380
# Window 133/251 complete. Test Day Return: 1.0020
# Window 134: Optimized L1 Lambda = 0.2976351380
# Window 134/251 complete. Test Day Return: 0.9987
# Window 135: Optimized L1 Lambda = 0.2976351380
# Window 135/251 complete. Test Day Return: 0.9956
# Window 136: Optimized L1 Lambda = 0.2976351380
# Window 136/251 complete. Test Day Return: 1.0084
# Window 137: Optimized L1 Lambda = 0.2976351380
# Window 137/251 complete. Test Day Return: 0.9988
# Window 138: Optimized L1 Lambda = 0.2976351380
# Window 138/251 complete. Test Day Return: 1.0081
# Window 139: Optimized L1 Lambda = 0.2976351380
# Window 139/251 complete. Test Day Return: 0.9962
# Window 140: Optimized L1 Lambda = 0.2976351380
# Window 140/251 complete. Test Day Return: 1.0016
# Window 141: Optimized L1 Lambda = 0.2976351380
# Window 141/251 complete. Test Day Return: 1.0106
# Window 142: Optimized L1 Lambda = 0.2976351380
# Window 142/251 complete. Test Day Return: 0.9996
# Window 143: Optimized L1 Lambda = 0.2976351380
# Window 143/251 complete. Test Day Return: 0.9956
# Window 144: Optimized L1 Lambda = 0.2976351380
# Window 144/251 complete. Test Day Return: 1.0072
# Window 145: Optimized L1 Lambda = 0.2976351380
# Window 145/251 complete. Test Day Return: 0.9882
# Window 146: Optimized L1 Lambda = 0.2976351380
# Window 146/251 complete. Test Day Return: 0.9998
# Window 147: Optimized L1 Lambda = 0.2976351380
# Window 147/251 complete. Test Day Return: 0.9973
# Window 148: Optimized L1 Lambda = 0.2976351380
# Window 148/251 complete. Test Day Return: 1.0060
# Window 149: Optimized L1 Lambda = 0.2976351380
# Window 149/251 complete. Test Day Return: 0.9952
# Window 150: Optimized L1 Lambda = 0.2976351380
# Window 150/251 complete. Test Day Return: 0.9934
# Window 151: Optimized L1 Lambda = 0.2976351380
# Window 151/251 complete. Test Day Return: 1.0002
# Window 152: Optimized L1 Lambda = 0.2976351380
# Window 152/251 complete. Test Day Return: 1.0082
# Window 153: Optimized L1 Lambda = 0.2976351380
# Window 153/251 complete. Test Day Return: 1.0032
# Window 154: Optimized L1 Lambda = 0.2976351380
# Window 154/251 complete. Test Day Return: 1.0012
# Window 155: Optimized L1 Lambda = 0.2976351380
# Window 155/251 complete. Test Day Return: 1.0051
# Window 156: Optimized L1 Lambda = 0.2976351380
# Window 156/251 complete. Test Day Return: 0.9711
# Window 157: Optimized L1 Lambda = 0.2976351380
# Window 157/251 complete. Test Day Return: 1.0175
# Window 158: Optimized L1 Lambda = 0.2976351380
# Window 158/251 complete. Test Day Return: 0.9752
# Window 159: Optimized L1 Lambda = 0.2976351380
# Window 159/251 complete. Test Day Return: 0.9949
# Window 160: Optimized L1 Lambda = 0.0885866806
# Window 160/251 complete. Test Day Return: 1.0108
# Window 161: Optimized L1 Lambda = 0.2976351380
# Window 161/251 complete. Test Day Return: 0.9972
# Window 162: Optimized L1 Lambda = 0.2976351380
# Window 162/251 complete. Test Day Return: 0.9997
# Window 163: Optimized L1 Lambda = 0.0885866806
# Window 163/251 complete. Test Day Return: 0.9966
# Window 164: Optimized L1 Lambda = 0.0885866806
# Window 164/251 complete. Test Day Return: 1.0189
# Window 165: Optimized L1 Lambda = 0.0885866806
# Window 165/251 complete. Test Day Return: 1.0102
# Window 166: Optimized L1 Lambda = 0.0885866806
# Window 166/251 complete. Test Day Return: 0.9905
# Window 167: Optimized L1 Lambda = 0.0885866806
# Window 167/251 complete. Test Day Return: 0.9915
# Window 168: Optimized L1 Lambda = 0.2976351380
# Window 168/251 complete. Test Day Return: 1.0001
# Window 169: Optimized L1 Lambda = 0.2976351380
# Window 169/251 complete. Test Day Return: 1.0182
# Window 170: Optimized L1 Lambda = 0.2976351380
# Window 170/251 complete. Test Day Return: 0.9924
# Window 171: Optimized L1 Lambda = 0.2976351380
# Window 171/251 complete. Test Day Return: 1.0090
# Window 172: Optimized L1 Lambda = 0.2976351380
# Window 172/251 complete. Test Day Return: 0.9974
# Window 173: Optimized L1 Lambda = 0.2976351380
# Window 173/251 complete. Test Day Return: 0.9926
# Window 174: Optimized L1 Lambda = 0.2976351380
# Window 174/251 complete. Test Day Return: 1.0101
# Window 175: Optimized L1 Lambda = 0.2976351380
# Window 175/251 complete. Test Day Return: 0.9985
# Window 176: Optimized L1 Lambda = 0.2976351380
# Window 176/251 complete. Test Day Return: 0.9921
# Window 177: Optimized L1 Lambda = 0.2976351380
# Window 177/251 complete. Test Day Return: 1.0056
# Window 178: Optimized L1 Lambda = 0.2976351380
# Window 178/251 complete. Test Day Return: 0.9832
# Window 179: Optimized L1 Lambda = 0.2976351380
# Window 179/251 complete. Test Day Return: 1.0017
# Window 180: Optimized L1 Lambda = 0.2976351380
# Window 180/251 complete. Test Day Return: 0.9941
# Window 181: Optimized L1 Lambda = 0.2976351380
# Window 181/251 complete. Test Day Return: 0.9991
# Window 182: Optimized L1 Lambda = 0.2976351380
# Window 182/251 complete. Test Day Return: 0.9942
# Window 183: Optimized L1 Lambda = 0.2976351380
# Window 183/251 complete. Test Day Return: 1.0077
# Window 184: Optimized L1 Lambda = 0.2976351380
# Window 184/251 complete. Test Day Return: 1.0077
# Window 185: Optimized L1 Lambda = 0.2976351380
# Window 185/251 complete. Test Day Return: 1.0010
# Window 186: Optimized L1 Lambda = 0.2976351380
# Window 186/251 complete. Test Day Return: 0.9966
# Window 187: Optimized L1 Lambda = 0.2976351380
# Window 187/251 complete. Test Day Return: 1.0028
# Window 188: Optimized L1 Lambda = 0.2976351380
# Window 188/251 complete. Test Day Return: 0.9945
# Window 189: Optimized L1 Lambda = 0.2976351380
# Window 189/251 complete. Test Day Return: 0.9995
# Window 190: Optimized L1 Lambda = 0.2976351380
# Window 190/251 complete. Test Day Return: 0.9959
# Window 191: Optimized L1 Lambda = 0.2976351380
# Window 191/251 complete. Test Day Return: 0.9989
# Window 192: Optimized L1 Lambda = 0.2976351380
# Window 192/251 complete. Test Day Return: 0.9997
# Window 193: Optimized L1 Lambda = 0.2976351380
# Window 193/251 complete. Test Day Return: 0.9935
# Window 194: Optimized L1 Lambda = 0.2976351380
# Window 194/251 complete. Test Day Return: 0.9900
# Window 195: Optimized L1 Lambda = 0.2976351380
# Window 195/251 complete. Test Day Return: 1.0030
# Window 196: Optimized L1 Lambda = 0.2976351380
# Window 196/251 complete. Test Day Return: 1.0005
# Window 197: Optimized L1 Lambda = 0.2976351380
# Window 197/251 complete. Test Day Return: 1.0230
# Window 198: Optimized L1 Lambda = 0.2976351380
# Window 198/251 complete. Test Day Return: 1.0067
# Window 199: Optimized L1 Lambda = 0.2976351380
# Window 199/251 complete. Test Day Return: 1.0209
# Window 200: Optimized L1 Lambda = 0.2976351380
# Window 200/251 complete. Test Day Return: 1.0082
# Window 201: Optimized L1 Lambda = 0.2976351380
# Window 201/251 complete. Test Day Return: 0.9977
# Window 202: Optimized L1 Lambda = 0.2976351380
# Window 202/251 complete. Test Day Return: 1.0079
# Window 203: Optimized L1 Lambda = 0.2976351380
# Window 203/251 complete. Test Day Return: 1.0119
# Window 204: Optimized L1 Lambda = 0.2976351380
# Window 204/251 complete. Test Day Return: 0.9959
# Window 205: Optimized L1 Lambda = 0.2976351380
# Window 205/251 complete. Test Day Return: 1.0051
# Window 206: Optimized L1 Lambda = 0.2976351380
# Window 206/251 complete. Test Day Return: 0.9993
# Window 207: Optimized L1 Lambda = 0.2976351380
# Window 207/251 complete. Test Day Return: 1.0140
# Window 208: Optimized L1 Lambda = 0.2976351380
# Window 208/251 complete. Test Day Return: 1.0044
# Window 209: Optimized L1 Lambda = 0.2976351380
# Window 209/251 complete. Test Day Return: 1.0073
# Window 210: Optimized L1 Lambda = 0.2976351380
# Window 210/251 complete. Test Day Return: 1.0005
# Window 211: Optimized L1 Lambda = 0.2976351380
# Window 211/251 complete. Test Day Return: 0.9902
# Window 212: Optimized L1 Lambda = 0.2976351380
# Window 212/251 complete. Test Day Return: 0.9973
# Window 213: Optimized L1 Lambda = 0.2976351380
# Window 213/251 complete. Test Day Return: 1.0146
# Window 214: Optimized L1 Lambda = 0.2976351380
# Window 214/251 complete. Test Day Return: 0.9955
# Window 215: Optimized L1 Lambda = 0.2976351380
# Window 215/251 complete. Test Day Return: 1.0037
# Window 216: Optimized L1 Lambda = 0.2976351380
# Window 216/251 complete. Test Day Return: 1.0088
# Window 217: Optimized L1 Lambda = 0.2976351380
# Window 217/251 complete. Test Day Return: 1.0061
# Window 218: Optimized L1 Lambda = 0.2976351380
# Window 218/251 complete. Test Day Return: 1.0113
# Window 219: Optimized L1 Lambda = 0.2976351380
# Window 219/251 complete. Test Day Return: 1.0039
# Window 220: Optimized L1 Lambda = 0.2976351380
# Window 220/251 complete. Test Day Return: 1.0023
# Window 221: Optimized L1 Lambda = 0.2976351380
# Window 221/251 complete. Test Day Return: 0.9955
# Window 222: Optimized L1 Lambda = 0.2976351380
# Window 222/251 complete. Test Day Return: 1.0042
# Window 223: Optimized L1 Lambda = 0.2976351380
# Window 223/251 complete. Test Day Return: 0.9876
# Window 224: Optimized L1 Lambda = 0.2976351380
# Window 224/251 complete. Test Day Return: 1.0029
# Window 225: Optimized L1 Lambda = 0.2976351380
# Window 225/251 complete. Test Day Return: 0.9948
# Window 226: Optimized L1 Lambda = 0.2976351380
# Window 226/251 complete. Test Day Return: 1.0001
# Window 227: Optimized L1 Lambda = 0.2976351380
# Window 227/251 complete. Test Day Return: 1.0057
# Window 228: Optimized L1 Lambda = 0.2976351380
# Window 228/251 complete. Test Day Return: 0.9984
# Window 229: Optimized L1 Lambda = 0.2976351380
# Window 229/251 complete. Test Day Return: 0.9954
# Window 230: Optimized L1 Lambda = 0.2976351380
# Window 230/251 complete. Test Day Return: 1.0027
# Window 231: Optimized L1 Lambda = 0.2976351380
# Window 231/251 complete. Test Day Return: 1.0033
# Window 232: Optimized L1 Lambda = 0.2976351380
# Window 232/251 complete. Test Day Return: 0.9882
# Window 233: Optimized L1 Lambda = 0.2976351380
# Window 233/251 complete. Test Day Return: 0.9983
# Window 234: Optimized L1 Lambda = 0.2976351380
# Window 234/251 complete. Test Day Return: 0.9955
# Window 235: Optimized L1 Lambda = 0.2976351380
# Window 235/251 complete. Test Day Return: 1.0122
# Window 236: Optimized L1 Lambda = 0.2976351380
# Window 236/251 complete. Test Day Return: 1.0128
# Window 237: Optimized L1 Lambda = 0.2976351380
# Window 237/251 complete. Test Day Return: 0.9976
# Window 238: Optimized L1 Lambda = 0.2976351380
# Window 238/251 complete. Test Day Return: 1.0032
# Window 239: Optimized L1 Lambda = 0.2976351380
# Window 239/251 complete. Test Day Return: 0.9936
# Window 240: Optimized L1 Lambda = 0.2976351380
# Window 240/251 complete. Test Day Return: 1.0054
# Window 241: Optimized L1 Lambda = 0.2976351380
# Window 241/251 complete. Test Day Return: 1.0027
# Window 242: Optimized L1 Lambda = 0.0885866806
# Window 242/251 complete. Test Day Return: 0.9937
# Window 243: Optimized L1 Lambda = 0.2976351380
# Window 243/251 complete. Test Day Return: 1.0021
# Window 244: Optimized L1 Lambda = 0.2976351380
# Window 244/251 complete. Test Day Return: 0.9936
# Window 245: Optimized L1 Lambda = 0.2976351380
# Window 245/251 complete. Test Day Return: 1.0028
# Window 246: Optimized L1 Lambda = 0.2976351380
# Window 246/251 complete. Test Day Return: 0.9951
# Window 247: Optimized L1 Lambda = 0.2976351380
# Window 247/251 complete. Test Day Return: 1.0052
# Window 248: Optimized L1 Lambda = 0.2976351380
# Window 248/251 complete. Test Day Return: 0.9972
# Window 249: Optimized L1 Lambda = 0.2976351380
# Window 249/251 complete. Test Day Return: 1.0159
# Window 250: Optimized L1 Lambda = 0.2976351380
# Window 250/251 complete. Test Day Return: 1.0071
# Window 251: Optimized L1 Lambda = 0.2976351380
# Window 251/251 complete. Test Day Return: 0.9968

# %% [markdown]
# Plot Generator and Discriminator loss. Good training should exhibit a stable oscillating loss for each around a mean.

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
plt.plot(d_hist, label='Disc Loss')
plt.plot(g_hist, label='Gen Loss')
plt.title("Initial Training: GAN Losses")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
# 1. Convert gross returns to simple net returns
# wealth_history is from the GAN strategy, each element is daily portfolio value
net_returns = np.array(wealth_history) - 1

# Calculate 1/N Benchmark returns for comparison
# (Taking the mean of all stock returns for each test day)
benchmark_returns = [data_tensor[i + year].mean().item() for i in range(len(wealth_history))]
net_bench = np.array(benchmark_returns)

# 2. Risk-Free Rate
rf_daily = 0.0 

# 3. Stats for Strategy
excess_returns = net_returns - rf_daily
avg_excess = np.mean(excess_returns)
std_dev = np.std(excess_returns)
sharpe_ratio = (avg_excess / std_dev) * np.sqrt(len(net_returns))

# 4. Stats for Benchmark
bench_excess = net_bench - rf_daily
bench_sharpe = (np.mean(bench_excess) / np.std(bench_excess)) * np.sqrt(len(net_returns))

# 5. Define and Calculate Quantiles
q_levels = [0.1, 0.25, 0.5, 0.75, 0.9]
quantiles = np.quantile(net_returns, q_levels)
bench_quantiles = np.quantile(net_bench, q_levels)

# --- Final Printing ---
print(f"--- Backtest Results (AI GANr LASSO) ---")
print(f"Total Test Days:         {len(net_returns)}")
print(f"Annualized Sharpe Ratio: {sharpe_ratio:.4f} (Bench: {bench_sharpe:.4f})")
print(f"Average Daily Return:    {avg_excess:.6f}")
print(f"Daily Volatility:       {std_dev:.6f}")
print("-" * 40)
print(f"{'Quantile':<10} | {'AI Strategy':<12} | {'1/N Benchmark':<12}")
print("-" * 40)
for i, q in enumerate(q_levels):
    print(f"{int(q*100)}th %tile  | {quantiles[i]:>11.4%} | {bench_quantiles[i]:>11.4%}")
# Out:
# --- Backtest Results (AI GANr LASSO) ---
# Total Test Days:         251
# Annualized Sharpe Ratio: 2.2731 (Bench: 2.1622)
# Average Daily Return:    0.001364
# Daily Volatility:       0.009508
# ----------------------------------------
# Quantile   | AI Strategy  | 1/N Benchmark
# ----------------------------------------
# 10th %tile  |    -0.8579% |    -0.7769%
# 25th %tile  |    -0.4195% |    -0.2908%
# 50th %tile  |     0.1181% |     0.1234%
# 75th %tile  |     0.7170% |     0.5564%
# 90th %tile  |     1.2224% |     1.0341%

# %%
# 1. AI Strategy Cumulative Return
# wealth_history already contains (return + 1), which is the gross daily return
ai_cumulative_returns = np.cumprod(wealth_history)
ai_final_wealth = ai_cumulative_returns[-1]

# 2. Benchmark (1/N) Cumulative Return
# We need to turn the simple returns into gross returns (1 + r)
# data_tensor[test_idx].mean() gives the average daily return of all stocks
benchmark_daily_gross = [data_tensor[i + year].mean().item() + 1 for i in range(len(wealth_history))]
bench_cumulative_returns = np.cumprod(benchmark_daily_gross)
bench_final_wealth = bench_cumulative_returns[-1]

# 3. Compute Total Percentage Growth
ai_total_return = (ai_final_wealth - 1) * 100
bench_total_return = (bench_final_wealth - 1) * 100

print(f"--- Raw Cumulative Returns (2016-2017) ---")
print(f"AI Strategy Final Wealth:   ${ai_final_wealth:.4f} ({ai_total_return:+.2f}%)")
print(f"1/N Benchmark Final Wealth: ${bench_final_wealth:.4f} ({bench_total_return:+.2f}%)")
print("-" * 45)
print(f"Outperformance of the EWP (1/N):    {ai_total_return - bench_total_return:+.2f}%")
# Out:
# --- Raw Cumulative Returns (2016-2017) ---
# AI Strategy Final Wealth:   $1.3921 (+39.21%)
# 1/N Benchmark Final Wealth: $1.3223 (+32.23%)
# ---------------------------------------------
# Outperformance of the EWP (1/N):    +6.98%

# %%
# Mimic Pun's plotting type in Fig. 2 of his paper
ai_cumulative_returns_for_plotting = ai_cumulative_returns - 1


# Plot
plt.figure(figsize=(10, 5))
plt.plot(ai_cumulative_returns_for_plotting, marker='o', markersize=1)
plt.title("Cumulative Returns per Day")
plt.xlabel("Day")
plt.ylabel("Cumulative Return")
plt.grid(True)
plt.show()

# %% [markdown]
# # Tabulation of Rerun Results
#
# Intrinsic randomness of the GAN will naturally lead to different results each time it is run. Thus all aforementioned code is rerun manually to ensure results are not due to an individually lucky run.
#
# | No. | Return / % | Sharpe | Daily Volatility | Average Daily Return |
# |:---:|:----------:|:------:|:----------------:|:--------------------:|
# | 1   | 47.25      | 2.5136 | 0.010042         | 0.001593             |
# | 2   | 40.18      | 2.3547 | 0.009354         | 0.001390             |
# | 3   | 49.00      | 2.4670 | 0.010570         | 0.001646             |
# | 4   | 44.94      | 2.4099 | 0.010062         | 0.001531             |
# | 5   | 37.27      | 2.2348 | 0.009258         | 0.001306             |

# %% [markdown]
# # References
#
#
# Financial Thought Experiment: A GAN-based Approach to Vast Robust Portfolio
# Selection:
# https://www.ijcai.org/proceedings/2020/0637.pdf
#
#
# Data: Choose the specific file *sp500-0317*.
# https://data.mendeley.com/datasets/ndxfrshm74/3

# %% [markdown]
# <span style="color:red">
#
#
# # Disclaimer
#
# This work is strictly that of the author, Xiyang Foo. Neither Pun, Wang, nor Wong endorse nor verify it. Foo extends his gratitude to Professor Pun Chi Seng of Nanyang Technological University for his generosity and willingness to share and discuss his work.
#
# </span>
